# %% [markdown]
# # Iris Flower Classification using Scikit-learn libray

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df=sn.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# from the above data consists of
# *4 numeric attributes
# *1 nominal attribute.

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.drop_duplicates('species')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 100           6.3          3.3           6.0          2.5   virginica

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# *in the given data there is no null values.

# %% [markdown]
# *let's visualize the data for more understanding.

# %%
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#divide the data frmes based on their species data.
df1=df[df['species']=='setosa']
df2=df[df['species']=='versicolor']
df3=df[df['species']=='virginica']

# %%
print(df1)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
print(df2)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
print(df3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
#plt.plot(df1['sepal_length'])
plt.plot(df1['sepal_length'],label='setosa')
plt.plot(df2['sepal_length'],label='versicolor')
plt.plot(df3['sepal_length'],label='virginica')
plt.legend()
plt.title('sepal length')
plt.show()

# %%
plt.plot(df1['sepal_width'],label='setosa')
plt.plot(df2['sepal_width'],label='versicolor')
plt.plot(df3['sepal_width'],label='virginica')
plt.legend()
plt.title('sepal width')
plt.show()

# %%
plt.plot(df1['petal_length'],label='setosa')
plt.plot(df2['petal_length'],label='versicolor')
plt.plot(df3['petal_length'],label='virginica')
plt.legend()
plt.title('petal length')
plt.show()

# %%
plt.plot(df1['petal_width'],label='setosa')
plt.plot(df2['petal_width'],label='versicolor')
plt.plot(df3['petal_width'],label='virginica')
plt.legend()
plt.title('petal width')
plt.show()

# %% [markdown]
# ***from the above four graphs we can understand that
# setosa leaves are small compared to versicolor where as it is smaller than virginica.

# %%
sn.kdeplot(df1['sepal_length'],label='setosa')
sn.kdeplot(df2['sepal_length'],label='versicolor')
sn.kdeplot(df3['sepal_length'],label='virginica')
plt.legend()
plt.show()

# %%
sn.kdeplot(df1['sepal_width'],label='setosa')
sn.kdeplot(df2['sepal_width'],label='versicolor')
sn.kdeplot(df3['sepal_width'],label='virginica')
plt.legend()
plt.show()

# %%
sn.kdeplot(df1['petal_length'],label='setosa')
sn.kdeplot(df2['petal_length'],label='versicolor')
sn.kdeplot(df3['petal_length'],label='virginica')
plt.legend()
plt.show()

# %%
sn.kdeplot(df1['petal_width'],label='setosa')
sn.kdeplot(df2['petal_width'],label='versicolor')
sn.kdeplot(df3['petal_width'],label='virginica')
plt.legend()
plt.show()

# %% [markdown]
# ****if we observe carefully ,
# out of 4 graphs in 3,
# though setosa has high density but low scale.****

# %% [markdown]
# ****visualizing with violin plots

# %%
sn.violinplot(df1,inner='quartile')
plt.title('setosa')
# Out:
# Text(0.5, 1.0, 'setosa')

# %%
sn.violinplot(df2,inner='quartile')
plt.title('versicolor')
# Out:
# Text(0.5, 1.0, 'versicolor')

# %%
sn.violinplot(df3,inner='quartile')
plt.title('virginica')
# Out:
# Text(0.5, 1.0, 'virginica')

# %% [markdown]
# ***let's see the sinaplot(combinatio of both strip chart as well as violinplot)

# %%
sn.violinplot(df1)
sn.stripplot(df1)
plt.title('setosa')
plt.figure(figsize=(10,10))

# %%
sn.violinplot(df2)
sn.stripplot(df2)
plt.title('versicolr')
plt.figure(figsize=(10,10))

# %%
sn.violinplot(df3)
sn.stripplot(df3)
plt.title('virginica')
plt.figure(figsize=(10,10))

# %%
sn.pairplot(df,hue='species')
plt.show()

# %%
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
x1=df.iloc[:,:3]
print(x1.head())
# Out:
#    sepal_length  sepal_width  petal_length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5
# 4           5.0          3.6           1.4

# %%
y1=df.iloc[:,4]
print(y1.head())
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1)

# %%
print(x1_train,x1_test,y1_train,y1_test)
# Out:
#      sepal_length  sepal_width  petal_length
# 127           6.1          3.0           4.9
# 45            4.8          3.0           1.4
# 9             4.9          3.1           1.5
# 25            5.0          3.0           1.6
# 30            4.8          3.1           1.6
# ..            ...          ...           ...
# 122           7.7          2.8           6.7
# 35            5.0          3.2           1.2
# 12            4.8          3.0           1.4
# 5             5.4          3.9           1.7
# 11            4.8          3.4           1.6
#
# [112 rows x 3 columns]      sepal_length  sepal_width  petal_length
# 0             5.1          3.5           1.4
# 146           6.3          2.5           5.0
# 87            6.3          2.3           4.4
# 136           6.3          3.4           5.6
# 120           6.9          3.2           5.7
# 53            5.5          2.3           4.0
# 101           5.8          2.7           5.1
# ...

# %% [markdown]
# ****try the DECISION TREE CLASSIFIER

# %%
model=DecisionTreeClassifier()

# %%
print(model)
# Out:
# DecisionTreeClassifier()

# %%
model.fit(x1_train,y1_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=model.predict(x1_test)
accuracy=accuracy_score(y1_test,predictions)

# %%
print("Accuracy of the data is ",accuracy)
# Out:
# Accuracy of the data is  0.8947368421052632

# %% [markdown]
# ****Let's try the logistic Regression

# %%
model2=LogisticRegression()
model2.fit(x1_train,y1_train)
# Out:
# LogisticRegression()

# %%
pre2=model.predict(x1_test)
a1=accuracy_score(y1_test,pre2)

# %%
print("Accuracy of the data is",a1*100)
# Out:
# Accuracy of the data is 89.47368421052632

# %% [markdown]
# ***we created 2  ML Models ,trained them and observed their accuracy

# %% [markdown]
# #  hence we have completed the task.
